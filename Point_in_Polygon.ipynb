# %% [markdown]
# <a href="https://colab.research.google.com/github/jacobfvanzyl/KML_Extractor/blob/master/Point_in_Polygon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XSIT KML Validator
#
# ## How-to:
# 1. Link Google Drive to Colab
# 1. Copy path to a folder on GDrive where files to be imported are located
# 1.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Environment setup

# %%
# Only run this cell on every new instance
# !pip install pandas
# !pip install numpy
# !pip install fastkml
# !pip install xmltodict
# !pip install pprint

debug = True
# %pwd

# %% [markdown]
# ## Package imports

# %%
import os
import numpy as np
import pandas as pd
from fastkml import kml
import xmltodict
import json
from shapely.geometry import Point, Polygon
from shapely import speedups

import pprint
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ## Paths

# %%
batch_path = "drive/My Drive/PointInPolygon/"
batch_name = "SRV SUB Areas - Contiuously edited"
points_name = "TRAPS 2019-2020 Master"
input_path = batch_path + "input/"
output_path = batch_path + "output/"
debug_path = batch_path + 'output/debug/'

# %% [markdown]
# ## Load KML data

# %%
# Polygons file
kml_path = input_path + batch_name + ".kml"
json_path = input_path + batch_name + ".json"

# Points file
points_kml_path = input_path + points_name + ".kml"
points_json_path = input_path + points_name + ".json"

os.makedirs(os.path.dirname(debug_path), exist_ok=True)

data = {}
points_data = {}

# Write XML to JSON
with open(kml_path) as xml_file:
    with open(json_path, 'w') as json_file:
        json.dump(xmltodict.parse(xml_file.read()), json_file)

with open(points_kml_path) as points_xml_file:
    with open(points_json_path, 'w') as points_json_file:
        json.dump(xmltodict.parse(points_xml_file.read()), points_json_file)

# Traverse down into root level
with open(points_json_path) as point_json_data:
    point_contents = point_json_data.read()
    points_data = json.loads(point_contents)
    points_data = points_data["kml"]["Document"] # <-- Never do this iteratively

with open(json_path) as json_data:
    contents = json_data.read()
    data = json.loads(contents)
    data = data["kml"]["Document"]

print("Successfully created JSON file and loaded files: " + data['name'] + ", " + points_data['name'] + " into memory")

points_data = points_data['Folder']['Folder']
data = data['Folder']['Folder']

if debug:
    # print(json.dumps(data, indent=2, sort_keys=True))
    with open(debug_path + 'polygons.json', 'w') as poly_file:
        json.dump(data, poly_file)

    with open(debug_path + 'points.json', 'w') as points_file:
        json.dump(points_data, points_file)
# Out:
# Successfully created JSON file and loaded files: SIT NEW SUB-AREAS.kml, TRAPS 2019-2020 Master.kml into memory

# %% [markdown]
# ## Data levels
#
# Set the levels in the list below to correspond with the structure of the current KML file

# %%
# Levels
data_levels = ['Region', 'Organisation', 'Farm', 'Block', 'Polygon']

point_levels = ['Organisation', 'Zone', 'Coords', 'Altitude']

combined_levels = ['Region', 'Organisation', 'Farm', 'Block', 'Polygon', 'ZONE', 'COORDS']

# %% [markdown]
# ## Nested data extraction
#
# Traverse and extract nested JSON data and insert into Pandas DataFrame

# %% [markdown]
# ### Polygons

# %%
# Polygons

def extractPolygon(level, block):
    
    if debug:
        print("----- P: " + block['Polygon']['outerBoundaryIs']['LinearRing']['coordinates'])
        
    coord_list = list(block['Polygon']['outerBoundaryIs']['LinearRing']['coordinates'].replace(',0 ', ';').replace(',0', '').split(";"))
    
    formatted_list = []

    for i in coord_list:
        pair = i.split(",")
        lat = float(pair[1])
        lon = float(pair[0])
        flip_pair = [lat, lon]
        formatted_list.append(flip_pair.copy())

    row[data_levels[level]] = formatted_list
    polygon_table.append(row.copy())

    # print(row['Polygon'])


def extractBlock(level, parent): 
    if type(parent['Placemark']) is dict:

        if debug:
            print("---- B: " + parent['Placemark']['name'])

        row[data_levels[level]] = str(parent['Placemark']['name'])

        extractPolygon((level + 1), parent['Placemark'])
                
    elif type(parent['Placemark']) is list:

        for block in parent['Placemark']:

            if debug:
                print("---- B: " + block['name'])

            row[data_levels[level]] = str(block['name'])

            extractPolygon((level + 1), block)

def extractFarm(level, parent):
    if type(org['Folder']) is dict:     # - Single
        
        if debug:
            print("--- F: " + org['Folder']['name'])

        row[data_levels[level]] = org['Folder']['name']

        if 'Placemark' in org['Folder']:
            extractBlock((level + 1), org['Folder']) 
                        
        else:
            if debug:
                print('!--- B: No nested Blocks in Farm')

    elif type(org['Folder']) is list:   # - List

        for farm in org['Folder']:
            
            if debug:
                print("--- F: " + farm['name'])
            
            row[data_levels[level]] = farm['name'] 

            if 'Placemark' in farm:
                extractBlock((level + 1), farm)   

            else:
                print('!--- B: No nested Blocks in Farm')


polygon_table = []

count_regions = 0
count_orgs = 0
count_farms = 0
count_blocks = 0

for region in data:    

    row = {}
    level = 0

    if debug:
        print("- R: " + region['name'])

    row[data_levels[level]] = region['name'] 
    count_regions += 1

    for org in region['Folder']:

        if debug:
            print("-- O: " + org['name'])
        
        row[data_levels[(level + 1)]] = org['name']
        
        if "Folder" in org:     # FARMS
            extractFarm((level + 2), org)

        else:
            print("!-- F: No nested Farms in Org")

# print(polygon_table)

# %%
# Print Polygons DataFrame
poly_df = pd.DataFrame(polygon_table)
poly_df.to_excel(output_path + batch_name + '.xlsx', index=False)
poly_df
# Out:
#               Region  ...                                            Polygon
# 0       KIRKWOOD-WES  ...  [[-33.41098338567136, 25.43725693096086], [-33...
# 1       KIRKWOOD-WES  ...  [[-33.40790497369915, 25.43802584269752], [-33...
# 2       KIRKWOOD-WES  ...  [[-33.40219220166004, 25.38933659375389], [-33...
# 3       KIRKWOOD-WES  ...  [[-33.40234544132873, 25.38852443959581], [-33...
# 4       KIRKWOOD-WES  ...  [[-33.402532895722, 25.38743564794471], [-33.4...
# ...              ...  ...                                                ...
# 2919  BARKLEY BRIDGE  ...  [[-33.56286343006675, 25.69428371176782], [-33...
# 2920  BARKLEY BRIDGE  ...  [[-33.56259675787091, 25.69981656874453], [-33...
# 2921  BARKLEY BRIDGE  ...  [[-33.56414799884166, 25.69945207277419], [-33...
# 2922  BARKLEY BRIDGE  ...  [[-33.56354771695999, 25.69965138493305], [-33...
# 2923  BARKLEY BRIDGE  ...  [[-33.56417137637284, 25.69953261026501], [-33...
#
# [2924 rows x 5 columns]

# %% [markdown]
# ### Points

# %%
# Points
points_table = []

for org in points_data:

    row = {}

    if debug:
        print("- O: " + org['name'])
    
    row[point_levels[0]] = org['name']
    
    if 'Placemark' in org:
            if type(org['Placemark']) is dict:
                if debug:
                    print("-- Z: " + org['Placemark']['name'])
                row[point_levels[1]] = org['Placemark']['name']
                if debug:
                    print("--- C: " + org['Placemark']['Point']['coordinates'])
                pair = list(org['Placemark']['Point']['coordinates'].split(","))
                lat = float(pair[1])
                lon = float(pair[0])
                alt = float(pair[2])
                flipped_pair = [lat, lon]
                
                row[point_levels[2]] = flipped_pair
                row[point_levels[3]] = alt

                points_table.append(row.copy())
                print(row)
                
            elif type(org['Placemark']) is list:

                for zone in org['Placemark']:
                    if debug:
                        print("-- Z: " + zone['name'])
                    row[point_levels[1]] = zone['name']
                    if debug:
                        print("--- C: " + zone['Point']['coordinates'])
                    pair = list(zone['Point']['coordinates'].split(","))
                    lat = float(pair[1])
                    lon = float(pair[0])
                    alt = float(pair[2])
                    flipped_pair = [lat, lon]

                    row[point_levels[2]] = flipped_pair
                    row[point_levels[3]] = alt

                    points_table.append(row.copy())
                    print(row)
                    
    else:
        print('!--- B: No nested Zones in Org')
        
print(points_table)

# %%
# Print Points DataFrame
point_df = pd.DataFrame(points_table)
point_df.to_excel(output_path + points_name + '.xlsx', index=False)
point_df
# Out:
#         Organisation  ... Altitude
# 0      Adrian Walton  ...    64.96
# 1      Adrian Walton  ...    66.08
# 2      Adrian Walton  ...    71.39
# 3      Adrian Walton  ...    68.94
# 4      Adrian Walton  ...    70.73
# ...              ...  ...      ...
# 2191  Wreford Hudson  ...     0.00
# 2192  Wreford Hudson  ...    82.86
# 2193  Wreford Hudson  ...    78.90
# 2194  Wreford Hudson  ...     0.00
# 2195  Wreford Hudson  ...     0.00
#
# [2196 rows x 4 columns]

# %% [markdown]
# ## Point-in-Polygon match

# %%
# %%time

matched_table = []

for zone in point_df.index:
    
    row = {}

    point = Point(point_df[point_levels[2]][zone][0], point_df[point_levels[2]][zone][1])
    
    match = False
    count = 0

    for block in poly_df.index:
        poly = Polygon(poly_df[poly_df[data_levels[4]][block])
        
        if point.within(poly):
            
            match = True
            count += 1

            row[combined_levels[0]] = poly_df[data_levels[0]][block]
            row[combined_levels[1]] = poly_df[data_levels[1]][block]
            row[combined_levels[2]] = poly_df[data_levels[2]][block]
            row[combined_levels[3]] = poly_df[data_levels[3]][block]
            row[combined_levels[4]] = poly_df[data_levels[4]][block]
            row[combined_levels[5]] = point_df[point_levels[1]][zone]
            row[combined_levels[6]] = point_df[point_levels[2]][zone]

            matched_table.append(row.copy())

    if match == True:
        print(str(row) + '  | Count: ' + str(count))

    elif match == False:
        print('Zone: ' + point_df['Organisation'][zone] + ', ' + point_df['Zone'][zone] + ' has NO MATCH.')
# Out:
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Lupus Den Vlei', 'Block': '8', 'Polygon': [[-33.44555093433758, 25.55519753152435], [-33.44673795066535, 25.55464974576304], [-33.44707108497601, 25.55575240058439], [-33.44588824724875, 25.55625680674299], [-33.44555093433758, 25.55519753152435]], 'ZONE': 'AWL -  LDV 1 - 8 (BD/FF-F)', 'COORDS': [-33.446451, 25.555643]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Lupus Den Vlei', 'Block': '5', 'Polygon': [[-33.44769786695151, 25.55786312166964], [-33.44811939815688, 25.55921505003152], [-33.44690062640697, 25.55976495232736], [-33.44647458754005, 25.55841700408907], [-33.44769786695151, 25.55786312166964]], 'ZONE': 'AWL - LDV 2 - 5 (FF-M)', 'COORDS': [-33.44787051268876, 25.55910193195675]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '19', 'Polygon': [[-33.44674333316566, 25.55951390641798], [-33.44714269237255, 25.56079135092773], [-33.44610070579465, 25.56125021004423], [-33.4456976480982, 25.5599472764771], [-33.44674333316566, 25.55951390641798]], 'ZONE': 'AWL -  LDN 1 - 19 (FF-M)', 'COORDS': [-33.446825, 25.560775]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '21', 'Polygon': [[-33.44601950325415, 25.56139457447564], [-33.44641198877567, 25.56272113110153], [-33.44539252949492, 25.56317093736912], [-33.44498378924018, 25.5618540275545], [-33.44601950325415, 25.56139457447564]], 'ZONE': 'AWL -  LDN 2 - 21 (BD/FF-F)', 'COORDS': [-33.446164, 25.562659]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '27', 'Polygon': [[-33.44753837487646, 25.565837595475], [-33.44736114389244, 25.5659303001623], [-33.44749671731962, 25.5664062097982], [-33.44671261408674, 25.56674359822276], [-33.4466638326064, 25.56662943798666], [-33.44645407823271, 25.56588460408158], [-33.44614001839423, 25.56488317072476], [-33.44607506241957, 25.56468145353939], [-33.44702403697983, 25.5642508896817], [-33.44753837487646, 25.565837595475]], 'ZONE': 'AWL -  LDN 3 - 27 (FF-M)', 'COORDS': [-33.446816, 25.566374]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '25', 'Polygon': [[-33.44759931059625, 25.5622810252272], [-33.44801906432632, 25.56355528230486], [-33.44800652985904, 25.56362477741077], [-33.44795603244611, 25.56373994706378], [-33.44663397654774, 25.56433744332575], [-33.44617725477226, 25.56291624163861], [-33.44759931059625, 25.5622810252272]], 'ZONE': 'AWL -  LDN 4 - 25 (FF-F)', 'COORDS': [-33.44775, 25.563635]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '11', 'Polygon': [[-33.44547403177872, 25.55961773497373], [-33.44434394817223, 25.56007287179017], [-33.44410049930091, 25.55929963347976], [-33.44526545015321, 25.55879717093617], [-33.44547403177872, 25.55961773497373]], 'ZONE': 'AWL - LDN 5 - 11 (FF-F)', 'COORDS': [-33.4444695066331, 25.55971169790371]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '13', 'Polygon': [[-33.47450366561249, 25.61276119418459], [-33.4754231510441, 25.613044147761], [-33.47513034507421, 25.61433583852019], [-33.47422862540542, 25.61407587909107], [-33.47450366561249, 25.61276119418459]], 'ZONE': 'AWL - BER 1 - 13 (FF-F)', 'COORDS': [-33.475007, 25.61365500000001]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '26', 'Polygon': [[-33.47542463573507, 25.61828692879922], [-33.47531319174131, 25.61824549047649], [-33.47478761545889, 25.6176649499738], [-33.47459661216083, 25.61745136429052], [-33.47486924443536, 25.61619842850146], [-33.4750174342016, 25.61613484825423], [-33.47511064934434, 25.61608599578719], [-33.47515536987383, 25.61602691449652], [-33.47589117008822, 25.61624290616799], [-33.47542463573507, 25.61828692879922]], 'ZONE': 'AWL - BER 2 - 26 (FF-M)', 'COORDS': [-33.475671, 25.616455]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '11', 'Polygon': [[-33.47307058573371, 25.61370218676589], [-33.47218200800381, 25.61340745485137], [-33.47246634886978, 25.61209400044863], [-33.47336850001604, 25.61236917931454], [-33.47307058573371, 25.61370218676589]], 'ZONE': 'AWL - BER 3 - 11 (FF-M)', 'COORDS': [-33.473061, 25.612964]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol Pasture', 'Block': '28', 'Polygon': [[-33.47826668136261, 25.61687014153162], [-33.47732060988723, 25.61803764876501], [-33.4767252703923, 25.61781433808136], [-33.47703825165158, 25.61646175805914], [-33.47826668136261, 25.61687014153162]], 'ZONE': 'AWL - BER 4 - 28 (BD/FF-F)', 'COORDS': [-33.477297, 25.617824]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol Riverside', 'Block': '32', 'Polygon': [[-33.47786417679976, 25.61200158883343], [-33.47822568396679, 25.61072702070229], [-33.47916448345929, 25.61107860673744], [-33.47881239188047, 25.61235731127513], [-33.47786417679976, 25.61200158883343]], 'ZONE': 'AWL - BER 5 - 32 (BD/FF-F)', 'COORDS': [-33.478674, 25.612038]}  | Count: 1
# Zone: Adrian Walton, AWL - BER 6 - 36(FF-F) has NO MATCH.
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol Riverside', 'Block': '33', 'Polygon': [[-33.47685733471666, 25.61170535411805], [-33.47748268356173, 25.60943569587822], [-33.47817428526797, 25.60991888417379], [-33.47814986430208, 25.61002445551757], [-33.47833198668482, 25.61010287766594], [-33.47781129269416, 25.61198301150664], [-33.47685733471666, 25.61170535411805]], 'ZONE': 'AWL - BER 7 - 33 (FF-M)', 'COORDS': [-33.477269, 25.611528]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '2', 'Polygon': [[-33.47047302036408, 25.61520894415907], [-33.47022038897535, 25.61610815164785], [-33.46897226850638, 25.61548849914244], [-33.46866231431334, 25.61529573191332], [-33.46876280463788, 25.6151636421617], [-33.4690728119156, 25.61534326120231], [-33.46930633206328, 25.61461434771304], [-33.47047302036408, 25.61520894415907]], 'ZONE': 'AWL - BER 8 - 2 (BD/FF-F)', 'COORDS': [-33.469491, 25.615274]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Lupus Den Vlei', 'Block': '6', 'Polygon': [[-33.44654601655253, 25.55831901601314], [-33.44621933660744, 25.55729215729009], [-33.44739187556753, 25.5567487147222], [-33.44769146507939, 25.5577878047201], [-33.44654601655253, 25.55831901601314]], 'ZONE': 'AWL - LDV D1 - 6', 'COORDS': [-33.44729917314591, 25.55700182813445]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '10', 'Polygon': [[-33.44561737259829, 25.55987387422064], [-33.44528417612635, 25.55880162932501], [-33.44640341740079, 25.55833071608263], [-33.44672698867911, 25.55939726414652], [-33.44561737259829, 25.55987387422064]], 'ZONE': 'AWL - LDN D1 - 10', 'COORDS': [-33.44629889942649, 25.55862223199268]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '20', 'Polygon': [[-33.44709714247892, 25.56092070466455], [-33.44749626726495, 25.56221790245006], [-33.44649093767174, 25.56266423965967], [-33.446093091318, 25.56136948183392], [-33.44709714247892, 25.56092070466455]], 'ZONE': 'AWL - LDN D2 - 20', 'COORDS': [-33.44641759234893, 25.5614597013698]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '26', 'Polygon': [[-33.44856672126367, 25.56534235507372], [-33.44759696578388, 25.56579795981434], [-33.44709413898261, 25.56422457699547], [-33.44807694030929, 25.56379486971331], [-33.44856672126367, 25.56534235507372]], 'ZONE': 'AWL - LDN D3 - 26', 'COORDS': [-33.44781535517722, 25.56539737615146]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '29', 'Polygon': [[-33.44506095251722, 25.56540953601062], [-33.445390353365, 25.56527079465596], [-33.44554154100589, 25.56574695893446], [-33.44550582292872, 25.56598129097905], [-33.4456937932477, 25.56661855723434], [-33.44643723908977, 25.56629100314309], [-33.44659956142587, 25.56680225937643], [-33.44560140153401, 25.56721727306469], [-33.44506095251722, 25.56540953601062]], 'ZONE': 'AWL - LDN D4 - 29', 'COORDS': [-33.44580049364969, 25.56686781989545]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '23', 'Polygon': [[-33.44565948991328, 25.56428871960993], [-33.44535494797506, 25.5644254836343], [-33.4453383458139, 25.56437343247189], [-33.44525757077176, 25.56418051199835], [-33.44519944048609, 25.56408269853289], [-33.44508878964285, 25.56388049689646], [-33.44496409499306, 25.56373102601822], [-33.44482405184653, 25.56354655501815], [-33.44458489519073, 25.56330487681462], [-33.44443087721781, 25.56281102565297], [-33.44512462382441, 25.56249936438999], [-33.44565948991328, 25.56428871960993]], 'ZONE': 'AWL - LDN D5 - 23', 'COORDS': [-33.44550962880415, 25.56404601842354]}  | Count: 1
# {'Region': 'DUNBRODY', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'AD Lupus Den', 'Block': '22', 'Polygon': [[-33.4450971298175, 25.56242674189658], [-33.44428042059465, 25.56273950633822], [-33.44400991147312, 25.56213991241109], [-33.44394111558651, 25.56194984034671], [-33.44404701693905, 25.56180916634895], [-33.44402073112711, 25.56162167630988], [-33.44400423357442, 25.56138166664688], [-33.44469055734128, 25.56106692406342], [-33.4450971298175, 25.56242674189658]], 'ZONE': 'AWL - LDN D6 - 22', 'COORDS': [-33.44447853097122, 25.56238358669317]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '6', 'Polygon': [[-33.47682899312603, 25.61203108821832], [-33.47654035962871, 25.61332981170319], [-33.47563909012313, 25.6130392738535], [-33.47593801735314, 25.61174723099606], [-33.47682899312603, 25.61203108821832]], 'ZONE': 'AWL - BER D1 - 6', 'COORDS': [-33.47647319628412, 25.61305397836065]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '21', 'Polygon': [[-33.4759191140611, 25.61615000950217], [-33.47513548871584, 25.61592196947077], [-33.47514220345966, 25.61586951176108], [-33.47517339515642, 25.61579401720443], [-33.47521333091201, 25.61571873596801], [-33.47523695366075, 25.61563037208977], [-33.47522996360037, 25.61547145551175], [-33.4752173967324, 25.61536901243885], [-33.47515486102027, 25.61522957353575], [-33.47527579924741, 25.61466139833703], [-33.47539376360371, 25.61461159272644], [-33.47620995123835, 25.61486632448748], [-33.4759191140611, 25.61615000950217]], 'ZONE': 'AWL - BER D2 - 21', 'COORDS': [-33.47608381004657, 25.61504474747769]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '25', 'Polygon': [[-33.4744811677356, 25.61580830279334], [-33.47451019504305, 25.61593424981719], [-33.47453687679291, 25.61601864784256], [-33.47459576884813, 25.61613702460819], [-33.47469070227813, 25.61620107531454], [-33.47473646574355, 25.61623055199367], [-33.47449008040551, 25.61725944448079], [-33.47437651752136, 25.61721475773715], [-33.4725344292852, 25.61516530497677], [-33.4744811677356, 25.61580830279334]], 'ZONE': 'AWL - BER D3 - 25', 'COORDS': [-33.47449639374198, 25.6168645611475]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '20', 'Polygon': [[-33.47465160628168, 25.61532811192611], [-33.47454076320709, 25.61573422643088], [-33.47390176041609, 25.61553985233952], [-33.47419055372584, 25.61421529511637], [-33.47486859206668, 25.61442862167275], [-33.47465160628168, 25.61532811192611]], 'ZONE': 'AWL - BER D4 - 20', 'COORDS': [-33.47451074192769, 25.61550381701539]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '19', 'Polygon': [[-33.47375997654699, 25.61549536880632], [-33.47287782441945, 25.61518075324564], [-33.47315282106163, 25.61389808550815], [-33.47405112550587, 25.61417741473354], [-33.47375997654699, 25.61549536880632]], 'ZONE': 'AWL - BER D5 - 19', 'COORDS': [-33.47369634345245, 25.61521679332483]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '18', 'Polygon': [[-33.47303997888379, 25.61386145120838], [-33.47275713813451, 25.61515595612296], [-33.47235366459265, 25.61505975136456], [-33.47188316667734, 25.61464273528231], [-33.47210466601384, 25.61356388113819], [-33.47303997888379, 25.61386145120838]], 'ZONE': 'AWL - BER D6 - 18', 'COORDS': [-33.47268723785088, 25.6148924413709]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '10', 'Polygon': [[-33.47182772596747, 25.61448066524181], [-33.47110705167486, 25.61406459462331], [-33.47267468632186, 25.61063616934793], [-33.47182772596747, 25.61448066524181]], 'ZONE': 'AWL - BER D7 - 10', 'COORDS': [-33.47177362233024, 25.61419940338362]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '1', 'Polygon': [[-33.46932615090247, 25.61455962941067], [-33.46944218138458, 25.61421223496366], [-33.4695594470529, 25.61425442991108], [-33.46976740628613, 25.61368093874486], [-33.4708084338786, 25.61417238988193], [-33.47049514762644, 25.61516127323533], [-33.46932615090247, 25.61455962941067]], 'ZONE': 'AWL - BER D8 - 1', 'COORDS': [-33.47046790556024, 25.61487603095999]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '12', 'Polygon': [[-33.47438981318907, 25.61271085855314], [-33.47409658827321, 25.61401596013419], [-33.47319046546947, 25.61374428984166], [-33.47347943758625, 25.61241550827935], [-33.47438981318907, 25.61271085855314]], 'ZONE': 'AWL - BER D9 - 12', 'COORDS': [-33.47426435565176, 25.61283846787795]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '16', 'Polygon': [[-33.47765050257526, 25.61374667442906], [-33.47857352779948, 25.61401781310722], [-33.47825887204756, 25.61550684996904], [-33.4773158101963, 25.61519321543659], [-33.47765050257526, 25.61374667442906]], 'ZONE': 'AWL - BER D10 - 16', 'COORDS': [-33.47816892413616, 25.61520460481254]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '27', 'Polygon': [[-33.47699056450041, 25.61642343199354], [-33.47668773362584, 25.61781363888966], [-33.47571044947732, 25.61747963900233], [-33.47602595322704, 25.61611616555011], [-33.47699056450041, 25.61642343199354]], 'ZONE': 'AWL - BER D11 - 27', 'COORDS': [-33.47662792988041, 25.61756703856202]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '29', 'Polygon': [[-33.47618517040661, 25.61943397356649], [-33.47552922017879, 25.61851093627137], [-33.47572741344252, 25.61753043249202], [-33.47729211366249, 25.61803978247763], [-33.47618517040661, 25.61943397356649]], 'ZONE': 'AWL - BER D12 - 29', 'COORDS': [-33.47584162060188, 25.61847845580486]}  | Count: 1
# {'Region': 'SUNLAND', 'Organisation': 'Bernol Farming (Pty) Ltd', 'Farm': 'Bernol (AWL)', 'Block': '31', 'Polygon': [[-33.47926777194243, 25.61089763568393], [-33.47944117024924, 25.61095352854595], [-33.47954816697551, 25.61107546087351], [-33.47966280953634, 25.61121299673339], [-33.47973062996689, 25.6113094738588], [-33.47979958311548, 25.61147895758055], [-33.47983409792089, 25.61162784008102], [-33.47984746900296, 25.61186168700053], [-33.47986738654834, 25.612223120069], [-33.47986842561609, 25.61263437391055], [-33.47887552666129, 25.61236817016976], [-33.47926777194243, 25.61089763568393]], 'ZONE': 'AWL - BER D13 - 31', 'COORDS': [-33.47974496524172, 25.61239162958399]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '16', 'Polygon': [[-33.41658793694453, 25.43591119785629], [-33.41502349776828, 25.4362827741048], [-33.41489247555273, 25.43521736776237], [-33.41655074421597, 25.4354932589385], [-33.41658793694453, 25.43591119785629]], 'ZONE': 'APG - RIV 1 - 16 (FF-F)', 'COORDS': [-33.416492, 25.435776]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '3', 'Polygon': [[-33.41074051163723, 25.43595783599125], [-33.4124577025654, 25.43570441451966], [-33.41247017073162, 25.43595773047871], [-33.41077692974934, 25.43621799758385], [-33.41074051163723, 25.43595783599125]], 'ZONE': 'APG - RIV 2 - 3 (FF-F/BD)', 'COORDS': [-33.411191, 25.435994]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '13', 'Polygon': [[-33.41323141856847, 25.43487638012345], [-33.41268145802307, 25.43488835683309], [-33.41268645749901, 25.43493627333508], [-33.41246224565093, 25.43493102845807], [-33.41232016257962, 25.43370527975477], [-33.4130814272891, 25.43364850959042], [-33.41323141856847, 25.43487638012345]], 'ZONE': 'APG - RIV 3 - 13 (FF-M)', 'COORDS': [-33.413065, 25.434692]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '12', 'Polygon': [[-33.41223735089987, 25.43285405756901], [-33.41451266891151, 25.4332858442061], [-33.41459247726125, 25.43389822123488], [-33.41231193415673, 25.4334652230383], [-33.41223735089987, 25.43285405756901]], 'ZONE': 'APG - RIV 4 - 12 (FF-F)', 'COORDS': [-33.414002, 25.433359]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '22', 'Polygon': [[-33.41626998421099, 25.43358600684336], [-33.41635364654677, 25.43417535709422], [-33.41473599927135, 25.43387390366922], [-33.41464123225516, 25.43330544691507], [-33.41626998421099, 25.43358600684336]], 'ZONE': 'APG - RIV 5 - 22 (FF-M)', 'COORDS': [-33.416194, 25.43395]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '8', 'Polygon': [[-33.41045961887039, 25.43241353003987], [-33.41217951423109, 25.43350358938424], [-33.41223451306185, 25.43398275159987], [-33.41044462784285, 25.43284477138471], [-33.41041462650639, 25.43265909888196], [-33.41045961887039, 25.43241353003987]], 'ZONE': 'APG - RIV D1 - 8', 'COORDS': [-33.4106682138619, 25.43271984284921]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '7', 'Polygon': [[-33.41225449760296, 25.43401469168047], [-33.41231685905353, 25.43444908274179], [-33.41063962195851, 25.43338980781396], [-33.41066461800424, 25.43319215608478], [-33.41053962552942, 25.4331202843859], [-33.41050462589976, 25.4329765383348], [-33.41051462421255, 25.43291065433348], [-33.41225449760296, 25.43401469168047]], 'ZONE': 'APG - RIV D2 - 7', 'COORDS': [-33.41214285345203, 25.43408621739882]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '6', 'Polygon': [[-33.4104867040278, 25.43340896164598], [-33.41227210167645, 25.43452722933145], [-33.4122861452696, 25.43472384266416], [-33.41065203084936, 25.43476703266638], [-33.4104867040278, 25.43340896164598]], 'ZONE': 'APG - RIV D3 - 6', 'COORDS': [-33.41109490174257, 25.4345221590999]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '5', 'Polygon': [[-33.41231480011324, 25.43484259893786], [-33.41240006529394, 25.43537475141201], [-33.41068695136422, 25.43553070417489], [-33.41063563286207, 25.43490483800374], [-33.41231480011324, 25.43484259893786]], 'ZONE': 'APG - RIV D4 - 5', 'COORDS': [-33.4122447753273, 25.43519682828136]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '4', 'Polygon': [[-33.41072961366157, 25.43564183725869], [-33.41241950036601, 25.43548613142658], [-33.4124444977752, 25.43569576801241], [-33.41078460631517, 25.43592334430493], [-33.41072961366157, 25.43564183725869]], 'ZONE': 'APG - RIV D5 - 4', 'COORDS': [-33.41115394285979, 25.43569781069859]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '2', 'Polygon': [[-33.41252027238065, 25.43639828639903], [-33.41085293138673, 25.43664221156896], [-33.41081608373674, 25.43632515701425], [-33.41247309513875, 25.43607644715086], [-33.41252027238065, 25.43639828639903]], 'ZONE': 'APG - RIV D6 - 2', 'COORDS': [-33.41232856462513, 25.43625144460059]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '11', 'Polygon': [[-33.41220647289758, 25.43254045005995], [-33.41229646713326, 25.43254643803327], [-33.41229646538942, 25.43245659408918], [-33.41241434300083, 25.4323490307097], [-33.41395222695073, 25.43264143828345], [-33.41392636271437, 25.43312141151889], [-33.412201478085, 25.43281597077701], [-33.41220647289758, 25.43254045005995]], 'ZONE': 'APG - RIV D7 - 11', 'COORDS': [-33.41260605851985, 25.43270967307539]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '30', 'Polygon': [[-33.41333641265317, 25.43469669033348], [-33.41323141759239, 25.43381621785001], [-33.41334640896659, 25.43372038315432], [-33.4146171916011, 25.43399728408446], [-33.41476016426701, 25.43499250550174], [-33.41333641265317, 25.43469669033348]], 'ZONE': 'APG - RIV D8 - 30', 'COORDS': [-33.41458765104045, 25.43477814677871]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '29', 'Polygon': [[-33.41334461811169, 25.43472605682576], [-33.414764175424, 25.43501576304757], [-33.41476998464596, 25.43532428775911], [-33.41337751150319, 25.43512897067852], [-33.41334461811169, 25.43472605682576]], 'ZONE': 'APG - RIV D9 - 29', 'COORDS': [-33.41365441455551, 25.43496070305043]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '14', 'Polygon': [[-33.41245647382398, 25.43494825119204], [-33.4127014564222, 25.43494226298801], [-33.41269958687163, 25.43490071150216], [-33.41322777595086, 25.43488907585687], [-33.4133502625139, 25.43583011207342], [-33.41278915515999, 25.43585399802756], [-33.41275097231453, 25.43581172559273], [-33.41270916922731, 25.43574950900129], [-33.41267967276622, 25.43573108327167], [-33.41261362269636, 25.43572740058208], [-33.41256603048447, 25.43572935373025], [-33.41245647382398, 25.43494825119204]], 'ZONE': 'APG - RIV D10 - 14', 'COORDS': [-33.4131880464073, 25.43567454434902]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '28', 'Polygon': [[-33.41467292013573, 25.43536715641979], [-33.4147334034962, 25.43539345214243], [-33.41475904230939, 25.43545338862547], [-33.41482097763705, 25.43592201808492], [-33.41479728512004, 25.43595902755889], [-33.41475822701046, 25.43597287587215], [-33.41459701047453, 25.43598299636773], [-33.4140352393241, 25.43590856496643], [-33.41401630577125, 25.43587322608552], [-33.41400674764341, 25.43582616517096], [-33.41398751548909, 25.43578827549172], [-33.41369789734465, 25.43575685665289], [-33.41368292248983, 25.43579505314268], [-33.41345085371503, 25.43577245042769], [-33.41337140842765, 25.43516986956044], [-33.41467292013573, 25.43536715641979]], 'ZONE': 'APG - RIV D11 - 28', 'COORDS': [-33.41471464156733, 25.43580449035281]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '15', 'Polygon': [[-33.414241339459, 25.43601442164295], [-33.41443404165757, 25.43604486919849], [-33.41482129993094, 25.43604438221993], [-33.41485525895192, 25.43633580438179], [-33.414429378357, 25.43643336737506], [-33.41402635365002, 25.43608030431127], [-33.414241339459, 25.43601442164295]], 'ZONE': 'APG - RIV D12 - 15', 'COORDS': [-33.41438575505527, 25.4361646591025]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '23', 'Polygon': [[-33.41463323496252, 25.43328500200832], [-33.41454421294591, 25.43271684625372], [-33.41620538464591, 25.43306991157146], [-33.41626755240193, 25.43357007981932], [-33.41463323496252, 25.43328500200832]], 'ZONE': 'APG - RIV D13 - 23', 'COORDS': [-33.41486717160626, 25.43316552758149]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '21', 'Polygon': [[-33.41642286655245, 25.43460673660417], [-33.41477483896406, 25.43433521901367], [-33.41470465700454, 25.43389982245584], [-33.41637357618292, 25.434205876834], [-33.41642286655245, 25.43460673660417]], 'ZONE': 'APG - RIV D14 - 21', 'COORDS': [-33.41487779167427, 25.43404218770908]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '20', 'Polygon': [[-33.41646086042411, 25.43484460815407], [-33.41480272333417, 25.43454758716007], [-33.41477704797022, 25.4343470688401], [-33.41553292474661, 25.43447898763681], [-33.41597963309819, 25.43455006837029], [-33.41642748719182, 25.43461675214819], [-33.41646086042411, 25.43484460815407]], 'ZONE': 'APG - RIV D15 - 20', 'COORDS': [-33.4163801124736, 25.43472657842919]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '19', 'Polygon': [[-33.41481312592554, 25.43457326468374], [-33.41646124577608, 25.43488113743827], [-33.41651142488346, 25.43521681735026], [-33.41484174679303, 25.43490578931821], [-33.41481312592554, 25.43457326468374]], 'ZONE': 'APG - RIV D16 - 19', 'COORDS': [-33.41499048032402, 25.43471435350864]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Riverside', 'Block': '18', 'Polygon': [[-33.41627541714289, 25.43518785397436], [-33.41647140487979, 25.43522705237708], [-33.41650494694372, 25.43547522444728], [-33.41630860263274, 25.43543810006517], [-33.41627541714289, 25.43518785397436]], 'ZONE': 'APG - RIV D17 - 17', 'COORDS': [-33.41634266900434, 25.43531637436675]}  | Count: 1
# Zone: Andre Potgieter, APG - RIV D18 - 18 has NO MATCH.
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Armadale (APO)', 'Block': '40', 'Polygon': [[-33.42658152769513, 25.44020701340497], [-33.42694092877704, 25.4401361397322], [-33.42710693855277, 25.44007738324706], [-33.42726239330492, 25.44134285949792], [-33.42712641534324, 25.44139834685125], [-33.42683795837221, 25.4414511030222], [-33.42672479316558, 25.44144735779439], [-33.42658152769513, 25.44020701340497]], 'ZONE': 'APG - ARM 1 - 40 (FF-F/BD)', 'COORDS': [-33.427065, 25.441197]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Armadale (APO)', 'Block': '50', 'Polygon': [[-33.42524920933704, 25.43609666733017], [-33.42506556998713, 25.43473144209619], [-33.42553807856055, 25.43482118003561], [-33.42568371136742, 25.43605468332867], [-33.42557319413736, 25.43609219467374], [-33.42535546667126, 25.43611238256141], [-33.42524920933704, 25.43609666733017]], 'ZONE': 'APG - ARM 2 - 50 (FF-M)', 'COORDS': [-33.425463, 25.435913]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Armadale (APO)', 'Block': '44', 'Polygon': [[-33.42517548151469, 25.43739597220255], [-33.42533494902398, 25.43877449868491], [-33.42448175071794, 25.43892940928088], [-33.42449468016432, 25.43906880965479], [-33.42425768061226, 25.43910495575136], [-33.42408660605412, 25.43757938564862], [-33.42517548151469, 25.43739597220255]], 'ZONE': 'APG - ARM 3 - 44 (FF-M)', 'COORDS': [-33.42515, 25.438708]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Armadale (APO)', 'Block': '51', 'Polygon': [[-33.42571674084888, 25.43604491747339], [-33.42556002685706, 25.43487405911578], [-33.4256939827265, 25.43484921164334], [-33.42592198263874, 25.43487782445706], [-33.42607559450786, 25.43488345954592], [-33.42616264258894, 25.43482758589327], [-33.42624769450101, 25.43475588553394], [-33.4265177348068, 25.43471006694798], [-33.42657695264724, 25.4348830840771], [-33.42663182672149, 25.43547619415663], [-33.42660754165119, 25.43568258409533], [-33.42655489819451, 25.43583323300999], [-33.42647762994304, 25.43590707403145], [-33.42571674084888, 25.43604491747339]], 'ZONE': 'APG - ARM D1 - 51', 'COORDS': [-33.42602790604143, 25.43582426978269]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Armadale (APO)', 'Block': '45', 'Polygon': [[-33.42671924257012, 25.43782025049259], [-33.42682046538652, 25.43866907584793], [-33.42542815410777, 25.43891530702476], [-33.42533306789195, 25.43803342262593], [-33.42671924257012, 25.43782025049259]], 'ZONE': 'APG - ARM D2 - 45', 'COORDS': [-33.42670710257147, 25.4385153415268]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Armadale (APO)', 'Block': '43', 'Polygon': [[-33.42709719684554, 25.44000066478654], [-33.42654714402744, 25.44011720602302], [-33.42638960698392, 25.43886391216157], [-33.42694992355825, 25.4387528949301], [-33.42709719684554, 25.44000066478654]], 'ZONE': 'APG - ARM D3 - 43', 'COORDS': [-33.42681472020336, 25.43986406218815]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Armadale (APO)', 'Block': '39', 'Polygon': [[-33.42579837707283, 25.44038018373711], [-33.42651269775802, 25.44022112997521], [-33.42666065110387, 25.44147235474626], [-33.42594643685712, 25.44161252539971], [-33.42579837707283, 25.44038018373711]], 'ZONE': 'APG - ARM D4 - 39', 'COORDS': [-33.4261887326186, 25.44132315654938]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Armadale (APO)', 'Block': '37', 'Polygon': [[-33.42494193672715, 25.44049809916561], [-33.42507282719713, 25.44173908985124], [-33.42457287722694, 25.44182860656007], [-33.42442636150581, 25.44058878231042], [-33.42494193672715, 25.44049809916561]], 'ZONE': 'APG - ARM D5 - 37', 'COORDS': [-33.42497659669662, 25.44156065924569]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Knightsmead', 'Block': '3', 'Polygon': [[-33.40790497369915, 25.43802584269752], [-33.4091695690618, 25.43822160113836], [-33.40933319213101, 25.43839657910202], [-33.40966575338191, 25.44046475096199], [-33.40838509091094, 25.44072773705226], [-33.40790497369915, 25.43802584269752]], 'ZONE': 'APG - KNI 1 - 3 (VKM/FF-F/BD)', 'COORDS': [-33.40941895996041, 25.44029006988585]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Knightsmead', 'Block': '3', 'Polygon': [[-33.40790497369915, 25.43802584269752], [-33.4091695690618, 25.43822160113836], [-33.40933319213101, 25.43839657910202], [-33.40966575338191, 25.44046475096199], [-33.40838509091094, 25.44072773705226], [-33.40790497369915, 25.43802584269752]], 'ZONE': 'APG - KNI D1 - 3', 'COORDS': [-33.40909322765108, 25.43840238308366]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Knightsmead', 'Block': '1', 'Polygon': [[-33.41098338567136, 25.43725693096086], [-33.41107512554697, 25.43785576530839], [-33.41076714408794, 25.43788624506277], [-33.41052903050476, 25.43793813167386], [-33.41033649224954, 25.43796831207504], [-33.41013160649846, 25.438021461056], [-33.40999593649688, 25.43804677185257], [-33.40991890127042, 25.43748366341853], [-33.41098338567136, 25.43725693096086]], 'ZONE': 'APG - KNI D2 - 1', 'COORDS': [-33.41025047588008, 25.43782908571556]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lorries', 'Block': '25', 'Polygon': [[-33.41486536600831, 25.43042526555254], [-33.41658665869797, 25.43092973302754], [-33.41652028534545, 25.43145147473647], [-33.41478932415802, 25.43096676977621], [-33.41486536600831, 25.43042526555254]], 'ZONE': 'APG - LOR 1 - 25 (FF-F/BD)', 'COORDS': [-33.41641, 25.431115]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lorries', 'Block': '28', 'Polygon': [[-33.41508355535486, 25.42980250863561], [-33.41672450567957, 25.43020926524844], [-33.41663342109678, 25.43076278767048], [-33.41500253727219, 25.43030868851372], [-33.41508355535486, 25.42980250863561]], 'ZONE': 'APG - LOR D1 - 28', 'COORDS': [-33.41662558609021, 25.43030919523057]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lorries', 'Block': '26', 'Polygon': [[-33.41489508475659, 25.43030416397678], [-33.41647825103564, 25.43073842773051], [-33.41659456054616, 25.4308500683689], [-33.4165824899101, 25.43090129797179], [-33.41486983569764, 25.43040366564036], [-33.41489508475659, 25.43030416397678]], 'ZONE': 'APG - LOR D2 - 26', 'COORDS': [-33.41503579508299, 25.43038752626936]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lorries', 'Block': '27', 'Polygon': [[-33.4147961588852, 25.43101818644493], [-33.41650112887006, 25.43148626538815], [-33.41636796732282, 25.43230488752771], [-33.41469277462865, 25.43181094430592], [-33.4147961588852, 25.43101818644493]], 'ZONE': 'APG - LOR D3 - 27', 'COORDS': [-33.41630247755951, 25.43209378315239]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lorries', 'Block': '24', 'Polygon': [[-33.41458200347064, 25.4324695909324], [-33.41465549083578, 25.43193474039934], [-33.41580087435236, 25.43234523201128], [-33.41575669985561, 25.43267532506609], [-33.41458200347064, 25.4324695909324]], 'ZONE': 'APG - LOR D4 - 24', 'COORDS': [-33.41568287116979, 25.43252577636809]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lucarl', 'Block': '32', 'Polygon': [[-33.41996227798036, 25.43772414269267], [-33.42070384329456, 25.43760964463629], [-33.42087328741882, 25.43916827318973], [-33.42016742263923, 25.43928959349627], [-33.41996227798036, 25.43772414269267]], 'ZONE': 'APG - LUC 1 - 32 (FF-F/BD)', 'COORDS': [-33.420687, 25.439002]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lucarl', 'Block': '35', 'Polygon': [[-33.41941257755318, 25.43439820846006], [-33.41963532156123, 25.43599630346945], [-33.41925427695399, 25.43605528085051], [-33.41897997558791, 25.43412994532108], [-33.41905132909124, 25.4341152556749], [-33.41917143917523, 25.43415996778214], [-33.41921938233683, 25.43442702679356], [-33.41941257755318, 25.43439820846006]], 'ZONE': 'APG - LUC 2 - 35 (FF-M)', 'COORDS': [-33.419413, 25.435881]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lucarl', 'Block': '36', 'Polygon': [[-33.41965328280921, 25.43599142251379], [-33.41940075717498, 25.43421796344296], [-33.41946932734397, 25.43421454319892], [-33.41957146066882, 25.43417569382241], [-33.41962877761752, 25.43410883009483], [-33.41968529716414, 25.43403196784513], [-33.41968045196852, 25.43380407852465], [-33.41972830758355, 25.43377417138651], [-33.41980123565175, 25.43376469845603], [-33.41985169384012, 25.43376843781229], [-33.41990213805823, 25.43377887119841], [-33.41996928728361, 25.43381294922245], [-33.42010269251421, 25.43467746925036], [-33.42027322454977, 25.43469554631085], [-33.42041482073044, 25.43586372860676], [-33.41965328280921, 25.43599142251379]], 'ZONE': 'APG - LUC D1 - 36', 'COORDS': [-33.41964268935492, 25.43437794459128]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Lucarl', 'Block': '31', 'Polygon': [[-33.41994291988799, 25.43770724388069], [-33.42015333800464, 25.43930376681103], [-33.41974003069502, 25.43939132765217], [-33.41948923915537, 25.43778881507857], [-33.41994291988799, 25.43770724388069]], 'ZONE': 'APG - LUC D2 - 31', 'COORDS': [-33.4200521471997, 25.43913994411866]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Glegg', 'Block': '31', 'Polygon': [[-33.41718112764176, 25.38522802432192], [-33.41652906648776, 25.38522527251096], [-33.41646911454113, 25.3832624698735], [-33.41662816973695, 25.38326698977141], [-33.41674831374166, 25.38333354341107], [-33.41685917847875, 25.38343744058314], [-33.41690257063416, 25.38356387888571], [-33.41696369846333, 25.3836779295306], [-33.41703405843126, 25.38373688303741], [-33.41708039996478, 25.38374461797132], [-33.41714567135659, 25.38375353878977], [-33.41718112764176, 25.38522802432192]], 'ZONE': 'APG - GLE 1 - 31 (FF-F/BD)', 'COORDS': [-33.416745, 25.38504]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Glegg', 'Block': '39', 'Polygon': [[-33.4137930683363, 25.38476622902921], [-33.41312007320329, 25.38460602560797], [-33.41346295752408, 25.38257115749448], [-33.41441102806576, 25.38281208607858], [-33.4137930683363, 25.38476622902921]], 'ZONE': 'APG - GLE 3 - 39 (FF-M)', 'COORDS': [-33.413718, 25.384547]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Glegg', 'Block': '36', 'Polygon': [[-33.41442762000003, 25.38283870009619], [-33.41466139095386, 25.38266769720099], [-33.41430611046845, 25.38372267177508], [-33.41416881545224, 25.38365232767358], [-33.41442762000003, 25.38283870009619]], 'ZONE': 'APG - GLE D1 - 36', 'COORDS': [-33.41431759475744, 25.38356360114106]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Glegg', 'Block': '33', 'Polygon': [[-33.41390813408117, 25.38450816415702], [-33.41646005230375, 25.38501428851884], [-33.4164961568347, 25.38519027158147], [-33.41635445758307, 25.38530406296378], [-33.4138321520168, 25.38474995474939], [-33.41390813408117, 25.38450816415702]], 'ZONE': 'APG - GLE D2 - 33', 'COORDS': [-33.41628021979499, 25.38511610335662]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Glegg', 'Block': '27', 'Polygon': [[-33.41744244524841, 25.38376439624826], [-33.41748587946483, 25.3851050074707], [-33.41721050683177, 25.38555867414139], [-33.41715160209281, 25.38377295692979], [-33.41744244524841, 25.38376439624826]], 'ZONE': 'APG - GLE D3 - 27', 'COORDS': [-33.41737329439649, 25.385087993527]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Glegg', 'Block': '26', 'Polygon': [[-33.41633378019572, 25.3861622249969], [-33.41651373102394, 25.38661388014987], [-33.41486523624283, 25.38744372430818], [-33.41475504046837, 25.38722762358259], [-33.41514472400677, 25.38689594252293], [-33.4153782197475, 25.3866739156659], [-33.41633378019572, 25.3861622249969]], 'ZONE': 'APG - GLE D4 - 26', 'COORDS': [-33.41638367931245, 25.38655477281903]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '5', 'Polygon': [[-33.402532895722, 25.38743564794471], [-33.40194484802498, 25.38730202092884], [-33.40214539342706, 25.38604967408315], [-33.40222401528855, 25.38603770520082], [-33.40271692151311, 25.38613938075208], [-33.40274701040693, 25.38623286936703], [-33.402532895722, 25.38743564794471]], 'ZONE': 'APG - SWA 1 - 5 (FF-F)', 'COORDS': [-33.402363, 25.387149]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '2', 'Polygon': [[-33.40219220166004, 25.38933659375389], [-33.40161012272944, 25.3892029548594], [-33.4016993389946, 25.38867985575934], [-33.40227788334113, 25.3888047602445], [-33.40219220166004, 25.38933659375389]], 'ZONE': 'APG - SWA 2 - 2 (FF-M)', 'COORDS': [-33.402054, 25.389096]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '13', 'Polygon': [[-33.40525530440948, 25.38698535299718], [-33.4038395294165, 25.38958399416403], [-33.40319013051783, 25.38942581251275], [-33.40372563340656, 25.38658844393196], [-33.40525530440948, 25.38698535299718]], 'ZONE': 'APG - SWA 3 - 13 (FF-M)', 'COORDS': [-33.40486057399191, 25.38714860609064]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '19', 'Polygon': [[-33.41006567068807, 25.38765236957257], [-33.41060255644992, 25.38669363452016], [-33.41118283358785, 25.3868422058713], [-33.41140792249021, 25.3869608553103], [-33.41079247640246, 25.38813743326548], [-33.41006567068807, 25.38765236957257]], 'ZONE': 'APG - SWA 4 - 19 (FF-F/BD)', 'COORDS': [-33.410827, 25.387845]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '22', 'Polygon': [[-33.41098653858457, 25.38969004369726], [-33.41023549818899, 25.39104705758564], [-33.40951786943605, 25.3905661555923], [-33.41025493395191, 25.3892130018463], [-33.41098653858457, 25.38969004369726]], 'ZONE': 'APG - SWA 6 - 22 (FF-M)', 'COORDS': [-33.410282, 25.389508]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '4', 'Polygon': [[-33.40234544132873, 25.38852443959581], [-33.40230528589191, 25.38846280496874], [-33.40177103789041, 25.38831435120001], [-33.40194246554322, 25.38733175624195], [-33.40252567797627, 25.38747315712037], [-33.40234544132873, 25.38852443959581]], 'ZONE': 'APG - SWA D1 - 4', 'COORDS': [-33.40231628552035, 25.3882433187815]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '24', 'Polygon': [[-33.40301403881931, 25.39027884963759], [-33.40290438019222, 25.39087077795059], [-33.40228022447407, 25.39071362476811], [-33.40239290919785, 25.39012039161464], [-33.40301403881931, 25.39027884963759]], 'ZONE': 'APG - SWA D2 - 24', 'COORDS': [-33.40255651647078, 25.39057221475401]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '6', 'Polygon': [[-33.40244267524376, 25.39012673079015], [-33.40259291634717, 25.38952193536297], [-33.40262997509959, 25.3895522997505], [-33.40270968550016, 25.3890907781706], [-33.4026883368906, 25.38900015943543], [-33.40263346171219, 25.38889468878633], [-33.40259035607476, 25.38882762611354], [-33.40240102375391, 25.3887769720901], [-33.40244271387809, 25.38847845775515], [-33.40275219874923, 25.38856387766544], [-33.40274554220428, 25.38862746209358], [-33.40323075759646, 25.38873126893894], [-33.40294844464387, 25.39025330032382], [-33.40244267524376, 25.39012673079015]], 'ZONE': 'APG - SWA D3 - 6', 'COORDS': [-33.4028963325846, 25.39004601599872]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '7', 'Polygon': [[-33.40257278216671, 25.38762698602259], [-33.40342137169699, 25.38782119539823], [-33.40328526820839, 25.38863587002221], [-33.40243559093853, 25.38844815051401], [-33.40257278216671, 25.38762698602259]], 'ZONE': 'APG - SWA D4 - 7', 'COORDS': [-33.40318559619112, 25.38843225991825]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '8', 'Polygon': [[-33.4027125995778, 25.3867145125489], [-33.40360851648052, 25.38691088771524], [-33.40346459479812, 25.38773791239863], [-33.40256983311789, 25.38753329221816], [-33.4027125995778, 25.3867145125489]], 'ZONE': 'APG - SWA D5 - 8', 'COORDS': [-33.40335259839758, 25.38756327353029]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '9', 'Polygon': [[-33.40287342349855, 25.38582400535636], [-33.40376246615546, 25.3860396231077], [-33.40362411253354, 25.38688420167184], [-33.40272607765738, 25.38668728538083], [-33.40287342349855, 25.38582400535636]], 'ZONE': 'APG - SWA D6 - 9', 'COORDS': [-33.40350060455637, 25.38663399379367]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '11', 'Polygon': [[-33.40389820101122, 25.38565396653554], [-33.40400436637139, 25.38504795943642], [-33.40591916827177, 25.3856011679014], [-33.40591851534695, 25.38570313018249], [-33.40586640783781, 25.38585319769385], [-33.40571850061346, 25.3860732816898], [-33.40389820101122, 25.38565396653554]], 'ZONE': 'APG - SWA D7 - 11', 'COORDS': [-33.40416069948348, 25.38554327453995]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '13', 'Polygon': [[-33.40525530440948, 25.38698535299718], [-33.4038395294165, 25.38958399416403], [-33.40319013051783, 25.38942581251275], [-33.40372563340656, 25.38658844393196], [-33.40525530440948, 25.38698535299718]], 'ZONE': 'APG - SWA D8 - 13', 'COORDS': [-33.40352294675879, 25.389251867895]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '15', 'Polygon': [[-33.4031681028441, 25.38956314697755], [-33.40378153987321, 25.38970124696686], [-33.40315551069784, 25.39088931402115], [-33.40293494562326, 25.39083141646422], [-33.4031681028441, 25.38956314697755]], 'ZONE': 'APG - SWA D9 - 15', 'COORDS': [-33.40318352318131, 25.39062511620557]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '17', 'Polygon': [[-33.41024625689452, 25.38921815505075], [-33.40950337179508, 25.39054811713603], [-33.40875834857812, 25.39003952099153], [-33.40949216376257, 25.38872692829336], [-33.41024625689452, 25.38921815505075]], 'ZONE': 'APG - SWA D10 - 17', 'COORDS': [-33.40958197778976, 25.38900939486291]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '21', 'Polygon': [[-33.41159204880286, 25.38862283381891], [-33.41100805951152, 25.38964886237693], [-33.41030118930328, 25.38914738028977], [-33.41084402507335, 25.38814295865487], [-33.41159204880286, 25.38862283381891]], 'ZONE': 'APG - SWA D11 - 21', 'COORDS': [-33.41104956770219, 25.38934038395702]}  | Count: 1
# {'Region': 'KIRKWOOD-WES', 'Organisation': 'Swartkop Boerdery (Pty) Ltd', 'Farm': 'Swartkop', 'Block': '20', 'Polygon': [[-33.4116234612319, 25.38862003652079], [-33.41085908230929, 25.38812559046648], [-33.4115191921298, 25.38690816244435], [-33.41207316574815, 25.38701550886396], [-33.4123927922766, 25.38720505668526], [-33.4116234612319, 25.38862003652079]], 'ZONE': 'APG - SWA D12 - 20', 'COORDS': [-33.41162584963904, 25.38832463371197]}  | Count: 1
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Agricultural Research Council', 'Farm': 'Landbou Navorsing Stasie', 'Block': '10', 'Polygon': [[-33.5670144848844, 25.69136381572197], [-33.56711902313746, 25.69065271236775], [-33.56840927448138, 25.6909228886681], [-33.56831054055675, 25.69163570386835], [-33.5670144848844, 25.69136381572197]], 'ZONE': 'ARC - ARC 1 - 10', 'COORDS': [-33.56813122202558, 25.69143780524226]}  | Count: 1
# ...
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Wreford Hudson', 'Farm': 'Boplaas 2', 'Block': '26', 'Polygon': [[-33.56354771695999, 25.69965138493305], [-33.56415606465102, 25.69952255399389], [-33.56442639437613, 25.70205009068689], [-33.56384229751956, 25.70217514084586], [-33.56354771695999, 25.69965138493305]], 'ZONE': 'WHU - BOP D2 - 26 (BD)', 'COORDS': [-33.56403010070868, 25.69987741845922]}  | Count: 1
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Wreford Hudson', 'Farm': 'Boplaas 2', 'Block': '27', 'Polygon': [[-33.56417137637284, 25.69953261026501], [-33.5646723934959, 25.69942114051701], [-33.56512470252532, 25.70184932657634], [-33.56445579551181, 25.70200534720418], [-33.56417137637284, 25.69953261026501]], 'ZONE': 'WHU - BOP D3 - 27', 'COORDS': [-33.56454756624299, 25.69975206557955]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Ebenhaezer', 'Block': '53', 'Polygon': [[-33.40865272802571, 25.44790945338168], [-33.40871797535655, 25.4484839796116], [-33.40682840055533, 25.44880504977854], [-33.40675596789207, 25.44823110210142], [-33.40865272802571, 25.44790945338168]], 'ZONE': 'WHU - EBE 1 - 53 (BD/FF)', 'COORDS': [-33.408529, 25.44837400000001]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Ebenhaezer', 'Block': '48', 'Polygon': [[-33.41019995410689, 25.45125917811252], [-33.4102967821914, 25.4520326828232], [-33.40845592199602, 25.45233502596479], [-33.40839030648355, 25.45223797153192], [-33.40830742743449, 25.4515773055023], [-33.41019995410689, 25.45125917811252]], 'ZONE': 'WHU - EBE D1 - 48', 'COORDS': [-33.40851098381818, 25.45178506333848]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Ebenhaezer', 'Block': '56', 'Polygon': [[-33.40861341104514, 25.44764915217737], [-33.408634987803, 25.44788852395953], [-33.40673269750705, 25.44821615785942], [-33.40670223567864, 25.44797712548453], [-33.40861341104514, 25.44764915217737]], 'ZONE': 'WHU - EBE D2 - 56', 'COORDS': [-33.40692484979532, 25.448084405648]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Ebenhaezer', 'Block': '57', 'Polygon': [[-33.40849991920232, 25.44671427767992], [-33.40861249574547, 25.44763895215916], [-33.40671698103327, 25.44796296434025], [-33.40659583658214, 25.44701987603291], [-33.40849991920232, 25.44671427767992]], 'ZONE': 'WHU - EBE D3 - 57', 'COORDS': [-33.40837287835831, 25.44696080227568]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Koppie Alleen', 'Block': '8', 'Polygon': [[-33.43742121914048, 25.47465304971724], [-33.43879173287939, 25.47436983888747], [-33.43904771515764, 25.47585562986603], [-33.43768227413809, 25.47612957327011], [-33.43742121914048, 25.47465304971724]], 'ZONE': 'WHU - KOP 1 - 8 (FF)', 'COORDS': [-33.43887207126702, 25.47568052039037]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Koppie Alleen', 'Block': '12', 'Polygon': [[-33.43629275113165, 25.47595432341632], [-33.43752377575125, 25.47567371691894], [-33.43772402265547, 25.47665329351939], [-33.43773447443749, 25.47681933788766], [-33.43721313734172, 25.47673272113624], [-33.43691478231619, 25.47670272894287], [-33.43642663450238, 25.47684744845061], [-33.43629275113165, 25.47595432341632]], 'ZONE': 'WHU - KOP 2 - 12 (BD/FF)', 'COORDS': [-33.43746985492427, 25.47581960702478]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Koppie Alleen', 'Block': '1', 'Polygon': [[-33.43654968680006, 25.47807933165339], [-33.43760528847292, 25.47790859645055], [-33.43775189071349, 25.47913600548525], [-33.4366803835039, 25.47930171577558], [-33.43654968680006, 25.47807933165339]], 'ZONE': 'WHU - KOP 3 - 1 (FF)', 'COORDS': [-33.43765693371673, 25.47904465968994]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Koppie Alleen', 'Block': '11', 'Polygon': [[-33.43645079589714, 25.47706504775358], [-33.43705905301044, 25.47688262993098], [-33.43753433405499, 25.4769726564692], [-33.43751071592764, 25.47772368055254], [-33.43655786811426, 25.47794415959638], [-33.43645079589714, 25.47706504775358]], 'ZONE': 'WHU - KOP D1 - 11', 'COORDS': [-33.4373270826327, 25.47709149455782]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Mistkraal (whu)', 'Block': '33', 'Polygon': [[-33.4401460632777, 25.48023239041327], [-33.44015553946916, 25.48028236071703], [-33.44080347380992, 25.48014034256011], [-33.44106988309316, 25.48157038125685], [-33.43974596291495, 25.48184420942309], [-33.43950406119052, 25.48034577526416], [-33.4401460632777, 25.48023239041327]], 'ZONE': 'WHU - MIS 1 - 33 (BD/FF)', 'COORDS': [-33.44085830210634, 25.48142041578163]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Normandale', 'Block': '39', 'Polygon': [[-33.40819503105547, 25.45645193347151], [-33.40834844596616, 25.45771488568965], [-33.40732944572562, 25.45789344732435], [-33.40717497985708, 25.45663551668405], [-33.40819503105547, 25.45645193347151]], 'ZONE': 'WHU - NOR 2 - 39 (BD/FF)', 'COORDS': [-33.408132, 25.457571]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Normandale', 'Block': '45', 'Polygon': [[-33.40550910815286, 25.45656256987684], [-33.40553143826314, 25.45671094536604], [-33.40558750540498, 25.4567952237336], [-33.40577794709905, 25.45798269418659], [-33.4048876437753, 25.45828527387346], [-33.40460514909559, 25.45661413925919], [-33.40550910815286, 25.45656256987684]], 'ZONE': 'WHU - NOR 3 - 45 (FF)', 'COORDS': [-33.405407, 25.456719]}  | Count: 1
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Wreford Hudson', 'Farm': 'Rawdon 1', 'Block': '23', 'Polygon': [[-33.56126703341234, 25.69046328475289], [-33.56155144500659, 25.69077581203896], [-33.56153028817654, 25.69082538849199], [-33.56174051459467, 25.69109840523602], [-33.56171464554167, 25.69113701552439], [-33.56207745435406, 25.69159875040804], [-33.56206329048993, 25.69163440110785], [-33.56261857064041, 25.69231808102741], [-33.56241348962172, 25.69256536135428], [-33.56320938746999, 25.69350541459087], [-33.56314628319743, 25.69359056072438], [-33.56307867279934, 25.69361136373016], [-33.56297848772499, 25.69375649436351], [-33.56298267889865, 25.69383717681351], [-33.56297307944571, 25.69396505335181], [-33.56280444440584, 25.69419368358601], [-33.56232864283748, 25.69362170798231], [-33.56152429408655, 25.69266714234929], [-33.56126703341234, 25.69046328475289]], 'ZONE': 'WHU - RAW 1 - 23 (FF)', 'COORDS': [-33.562976, 25.693821]}  | Count: 1
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Wreford Hudson', 'Farm': 'Rawdon 1', 'Block': '13', 'Polygon': [[-33.56413648954904, 25.69190767388675], [-33.56417835827703, 25.69192779466729], [-33.56428904456902, 25.69195083831343], [-33.56466243504411, 25.6918707573832], [-33.56470009810472, 25.691891260101], [-33.56480899174616, 25.69189512898518], [-33.56492787161169, 25.69181110467978], [-33.56511683931797, 25.69169618124509], [-33.56541384021561, 25.69158546644778], [-33.56570085990903, 25.69302972986503], [-33.56550950323152, 25.6930731216623], [-33.56555964644917, 25.69334459970361], [-33.56572874469698, 25.69333117837177], [-33.56579170832684, 25.69368954911644], [-33.56573851030718, 25.69371922667965], [-33.56544489058579, 25.69346615576916], [-33.5652150082863, 25.6923403973932], [-33.56398876713718, 25.69254518878257], [-33.56389076167461, 25.69197533350516], [-33.56413648954904, 25.69190767388675]], 'ZONE': 'WHU - RAW 2 - 13 (BD/FF)', 'COORDS': [-33.565278, 25.691942]}  | Count: 1
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Wreford Hudson', 'Farm': 'Rawdon 2', 'Block': '21', 'Polygon': [[-33.56286343006675, 25.69428371176782], [-33.56314060677405, 25.69450185269426], [-33.56340351761281, 25.69499163081548], [-33.56359097574886, 25.69548439046389], [-33.56364215298086, 25.69575521034077], [-33.56376493278522, 25.69611421374646], [-33.56380109006712, 25.69628889117841], [-33.563951370457, 25.69653982544136], [-33.56396643731772, 25.69673636949316], [-33.56283126203671, 25.69694799756442], [-33.56251734618682, 25.69423597494748], [-33.56286343006675, 25.69428371176782]], 'ZONE': 'WHU - RAW D1 - 21 (BD)', 'COORDS': [-33.56306115839159, 25.69681066928683]}  | Count: 1
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Wreford Hudson', 'Farm': 'Rawdon 1', 'Block': '23', 'Polygon': [[-33.56126703341234, 25.69046328475289], [-33.56155144500659, 25.69077581203896], [-33.56153028817654, 25.69082538849199], [-33.56174051459467, 25.69109840523602], [-33.56171464554167, 25.69113701552439], [-33.56207745435406, 25.69159875040804], [-33.56206329048993, 25.69163440110785], [-33.56261857064041, 25.69231808102741], [-33.56241348962172, 25.69256536135428], [-33.56320938746999, 25.69350541459087], [-33.56314628319743, 25.69359056072438], [-33.56307867279934, 25.69361136373016], [-33.56297848772499, 25.69375649436351], [-33.56298267889865, 25.69383717681351], [-33.56297307944571, 25.69396505335181], [-33.56280444440584, 25.69419368358601], [-33.56232864283748, 25.69362170798231], [-33.56152429408655, 25.69266714234929], [-33.56126703341234, 25.69046328475289]], 'ZONE': 'WHU - RAW D2 - 23', 'COORDS': [-33.56156339431509, 25.69175314761923]}  | Count: 1
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Wreford Hudson', 'Farm': 'Rawdon 1', 'Block': '15', 'Polygon': [[-33.56366291975222, 25.69297025202471], [-33.56395459891245, 25.69290483092779], [-33.56402423372941, 25.69261858809871], [-33.56449899795295, 25.69255777532737], [-33.56458929336272, 25.69268580710549], [-33.56474342560586, 25.69364781758609], [-33.56383640551811, 25.69381567393811], [-33.56366291975222, 25.69297025202471]], 'ZONE': 'WHU - RAW D3 - 15', 'COORDS': [-33.56393332664442, 25.69346737206307]}  | Count: 1
# {'Region': 'BARKLEY BRIDGE', 'Organisation': 'Wreford Hudson', 'Farm': 'Rawdon 1', 'Block': '7', 'Polygon': [[-33.56462169663087, 25.69023329371212], [-33.56461851539807, 25.69086046526356], [-33.56448000844164, 25.69094760618464], [-33.56427424110975, 25.69093968040039], [-33.56427426664513, 25.69099800138359], [-33.56377791130505, 25.69099447527882], [-33.56378619096649, 25.69105693861083], [-33.56319491676736, 25.6910688960649], [-33.56316713836272, 25.6910132618774], [-33.56309411703617, 25.69094268874438], [-33.56309147772662, 25.69021913536419], [-33.56462169663087, 25.69023329371212]], 'ZONE': 'WHU - RAW D4 - 7', 'COORDS': [-33.56445486048409, 25.69080207780905]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Step Aside', 'Block': '18', 'Polygon': [[-33.4047338902824, 25.45017701754662], [-33.40479326771313, 25.45070770704181], [-33.40371799909578, 25.45090081145441], [-33.4036191669605, 25.45038728958518], [-33.4047338902824, 25.45017701754662]], 'ZONE': 'WHU - SAS 1 - 18 (BD/FF)', 'COORDS': [-33.404678, 25.450581]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Step Aside', 'Block': '29', 'Polygon': [[-33.40732837177497, 25.4523640335781], [-33.4071622940528, 25.45111168007825], [-33.40807420366863, 25.45093623218364], [-33.40823524746695, 25.45224123584386], [-33.40732837177497, 25.4523640335781]], 'ZONE': 'WHU - SAS 3 - 29 (FF)', 'COORDS': [-33.407328864649, 25.45127968439079]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Step Aside', 'Block': '28', 'Polygon': [[-33.40822338655781, 25.45227289708632], [-33.40840267969257, 25.45360408206683], [-33.40751178871195, 25.45374322029233], [-33.40733067527133, 25.45240408863563], [-33.40822338655781, 25.45227289708632]], 'ZONE': 'WHU - SAS D1 - 28', 'COORDS': [-33.40749043682904, 25.4526772379933]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Step Aside', 'Block': '31', 'Polygon': [[-33.40584069240138, 25.45002605915344], [-33.40641507977304, 25.44998889094862], [-33.40647844854384, 25.45050087341619], [-33.40592266469353, 25.45058665594442], [-33.40584069240138, 25.45002605915344]], 'ZONE': 'WHU - SAS D2 - 31', 'COORDS': [-33.40618021520092, 25.45034785014007]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Step Aside', 'Block': '21', 'Polygon': [[-33.40577533761796, 25.45007068846434], [-33.40581644061327, 25.45012845090841], [-33.40588507205926, 25.45061375221395], [-33.40487545473605, 25.45076131300734], [-33.40480835274613, 25.45021441137398], [-33.40577533761796, 25.45007068846434]], 'ZONE': 'WHU - SAS D3 - 21', 'COORDS': [-33.40565614796149, 25.45033135359966]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Step Aside', 'Block': '17', 'Polygon': [[-33.40481115394891, 25.45077639768423], [-33.40490130293475, 25.45143619144667], [-33.40385091496513, 25.45161078617534], [-33.40371900210772, 25.45096857591901], [-33.40481115394891, 25.45077639768423]], 'ZONE': 'WHU - SAS D4 - 17', 'COORDS': [-33.4047459590306, 25.45120698419116]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Step Aside', 'Block': '12', 'Polygon': [[-33.40350868972038, 25.45222933070406], [-33.40377517525189, 25.45374383936984], [-33.40369204420969, 25.45377525683185], [-33.40380470773554, 25.45444897314737], [-33.40333194186126, 25.45449948356878], [-33.40295491576586, 25.45231192451871], [-33.40350868972038, 25.45222933070406]], 'ZONE': 'WHU - SAS D5 - 12', 'COORDS': [-33.40332549016711, 25.45244604297021]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Volmoed 2', 'Block': '23', 'Polygon': [[-33.43883875926512, 25.48216421949318], [-33.43903456771891, 25.48237407488016], [-33.43931628999582, 25.48269674181346], [-33.43958249933328, 25.4830129318625], [-33.43847434586829, 25.48325910079765], [-33.43830671576945, 25.48227837548583], [-33.43883875926512, 25.48216421949318]], 'ZONE': 'WHU - VOL 1 - 23 (BD/FF)', 'COORDS': [-33.439341, 25.482755]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Volmoed 1', 'Block': '30', 'Polygon': [[-33.4460519783241, 25.49217586299265], [-33.44760019536187, 25.4919771048047], [-33.44774697769378, 25.49312460675787], [-33.44636764610576, 25.49337624893405], [-33.4460519783241, 25.49217586299265]], 'ZONE': 'WHU - VOL 2 - 30 (BD/FF)', 'COORDS': [-33.447583, 25.492902]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Volmoed 2', 'Block': '14', 'Polygon': [[-33.44108782956816, 25.48175697639076], [-33.44124229598549, 25.48261893847732], [-33.43969468302414, 25.48296205920106], [-33.43907463738253, 25.48220248345012], [-33.44108782956816, 25.48175697639076]], 'ZONE': 'WHU - VOL D1 - 14', 'COORDS': [-33.44098962657348, 25.48247708571547]}  | Count: 1
# {'Region': 'KIRKWOOD-OOS', 'Organisation': 'Wreford Hudson', 'Farm': 'Volmoed 2', 'Block': '21', 'Polygon': [[-33.43905585863196, 25.48324257498895], [-33.43928353641223, 25.48449479639894], [-33.43913467739192, 25.48447125572081], [-33.43894274694029, 25.4843804057363], [-33.43872805109996, 25.48422754455185], [-33.43863535961492, 25.48415238898376], [-33.43850448314971, 25.48338182321802], [-33.43905585863196, 25.48324257498895]], 'ZONE': 'WHU - VOL D4 - 21', 'COORDS': [-33.43899231915974, 25.48422808977647]}  | Count: 1
# CPU times: user 6min 4s, sys: 676 ms, total: 6min 5s
# Wall time: 6min 4s

# %% [markdown]
# ## Output

# %%
matched_df = pd.DataFrame(matched_table)
matched_df.to_excel(output_path + 'matched.xlsx', index=False)
matched_df
# Out:
#               Region  ...                                   COORDS
# 0       KIRKWOOD-WES  ...  [-33.41025047588008, 25.43782908571556]
# 1       KIRKWOOD-WES  ...  [-33.40909322765108, 25.43840238308366]
# 2       KIRKWOOD-WES  ...                  [-33.402054, 25.389096]
# 3       KIRKWOOD-WES  ...   [-33.40231628552035, 25.3882433187815]
# 4       KIRKWOOD-WES  ...                  [-33.402363, 25.387149]
# ...              ...  ...                                      ...
# 2700  BARKLEY BRIDGE  ...  [-33.56306115839159, 25.69681066928683]
# 2701  BARKLEY BRIDGE  ...   [-33.56274723564458, 25.6973241294694]
# 2702  BARKLEY BRIDGE  ...  [-33.56408336076098, 25.69707834234337]
# 2703  BARKLEY BRIDGE  ...  [-33.56403010070868, 25.69987741845922]
# 2704  BARKLEY BRIDGE  ...  [-33.56454756624299, 25.69975206557955]
#
# [2705 rows x 7 columns]
